# %% [markdown]
# 1. How do you distinguish between shutil.copy() and shutil.copytree()?
# ---
# * shutil.copy():- copy a single file.
# * shutil.copytree():- copy an entire folder and every folder and file contained in it
# ---
# ---
# 2. What function is used to rename files?
# ---
# * os.rename()
# ---
# ---
# 3. What is the difference between the delete functions in the send2trash and shutil modules?
# ---
# * send2trash():- sends file to recycle bin across all os.
# * shutil delete:- delete file permanently from system.
# ---
# ---
# 4. ZipFile objects have a close() method just like File objects’ close() method. What ZipFile method is equivalent to File objects’ open() method?
# ---
# * ZipFile()
# ---
# ---
# 5. Create a programme that searches a folder tree for files with a certain file extension (such as .pdf or .jpg). Copy these files from whatever location they are in to a new folder.
# ---

# %%
import os

# get all files inside a specific folder
dirPath = ['/content/drive']
for dirPth in dirPath:
  for path in os.scandir(dirPth):
      if path.is_file():
        if path.name.endswith("pdf"):
          print(path.name)
      elif path.is_dir():
        dirPath.append(path)
# Out:
# Getting started.pdf
# poa.pdf
# It works _ the famous little red book that - Jarrett, R. H. (Roy Herbert).pdf
# CL.pdf
# Divanshu_resume.pdf
# Divanshu_resume (1).pdf
# Adhar.pdf
# BankStatement.pdf
# bill.pdf
# Price Action Tweets from @PAVLeader.pdf
# 25 April- 1 May.pdf
# Vanika.pdf
# Stock Market Manual (1).pdf
# Stock Market Manual.pdf
# Vanika Resume.pdf
# Mera Hai (2).pdf
# Copy of Kims_Edel.pdf
# Mera Hai (1).pdf
# Mera Hai.pdf
# Resume_Divanshu (2).pdf
# Print.pdf
# Resume_Divanshu (1).pdf
# Resume_Divanshu.pdf
# Resume_Amazon.pdf
# merged.pdf
# PDc.pdf
# 8th sem mark sheet.pdf
# Degree.pdf
# Transcript.pdf
# Migration.pdf
# LOA- New.pdf
# Bill May 2021.pdf
# Certificate of Completion_4647304.pdf
# Certificate of Participation_4647304.pdf
# A salesman approach to Business Analysis.pdf
# Dealing with FOMO - Flash Note.pdf
# investingForGrowthPrint1.pdf
# Trading Option Greeks 2nd ed.pdf
# Final+MBL+AR+-2020-21.pdf
# ...
